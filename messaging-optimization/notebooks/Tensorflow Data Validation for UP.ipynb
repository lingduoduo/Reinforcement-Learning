# %% [markdown]
# # Tensorflow data validation example - UP

# %%
from tensorflow_data_validation import GenerateStatistics, TFExampleDecoder
from tensorflow_metadata.proto.v0 import statistics_pb2
import logging

import apache_beam as beam
import tensorflow_data_validation as tfdv
from apache_beam.options.pipeline_options import PipelineOptions, GoogleCloudOptions, StandardOptions, WorkerOptions, DebugOptions, SetupOptions
from tensorflow_data_validation import statistics
from spotify_tensorflow.tfx.tfdv import TfDataValidator
from spotify_tensorflow.tfx.utils import create_setup_file
from tensorflow_data_validation import StatsOptions

# %% [markdown]
# ### Set up

# %%
options = PipelineOptions()
google_cloud_options = options.view_as(GoogleCloudOptions)
google_cloud_options.project = "users-protection"
google_cloud_options.job_name = "statsjob3"
google_cloud_options.staging_location = "gs://hchudgar_test/staging"
google_cloud_options.temp_location = "gs://hchudgar_test/temp"
options.view_as(StandardOptions).runner = 'DataflowRunner'

debug_options = options.view_as(DebugOptions)
debug_options.experiments = ['beam_fn_api']

# worker_options = options.view_as(WorkerOptions)
# worker_options.worker_harness_container_image = 'gcr.io/users-protection/test-hchudgar-tfdv'

setup_options = options.view_as(SetupOptions)
setup_file_path = create_setup_file()
setup_options.setup_file = setup_file_path

# %% [markdown]
# ### Getting the statistics

# %% [markdown]
# #### Option 1: Generate stats from existing data
#
# 1. Specify where tfrecords are kept and where should the stats be stored
# 2. Generate
#
# This takes almost an hour to compute

# %%
data_location = "gs://hchudgar_test/email_open/tf/examples/email_open.temp.BaseInputDataV1/2019-04-17/20190423T204516.878251-eee6280da13e/training/*.tfrecords"
output_path = "gs://hchudgar_test/email_open/tf/examples/email_open.temp.BaseInputDataV1/2019-04-17/stats/"

stats = tfdv.generate_statistics_from_tfrecord(data_location=data_location,
                                               output_path=output_path,
                                               stats_options=StatsOptions(),
                                               pipeline_options=options)

# %% [markdown]
# #### Option 2: Read from existing location

# %%
statsFilePath ="gs://slayton_test/email_open/tf/examples/email_open.BaseInputDataV1/2019-04-01/" + \
               "20190411T155410.476299-3e9102f6a419/training/_stats.pb"
stats = tfdv.load_statistics(input_path=statsFilePath)

# %% [markdown]
# ### Visualize the stats of a single dataset
#
# This function uses [Facets](https://pair-code.github.io/facets/) to visualize statistics
# A quick look highlights features with many missing values, or features with many zeros along with distribution and some base statistics

# %%
tfdv.visualize_statistics(stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.contentWindow.document.write(facets_html);
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### Compare stats of two different datasets
#
# We can compare statistics of two different datasets to either
# 1. Compare if two days have different data distributions (e.g. email vs push features)
# 2. Compare distributions of training and a test dataset to identify data drift

# %%
rhs = tfdv.load_statistics(
    input_path="gs://slayton_test/email_open/tf/examples/email_open.BaseInputDataV1/2019-04-16/" +
               "20190417T184427.921839-7f41b7d82e6e/training/_stats.pb")

# %%
tfdv.visualize_statistics(lhs_name="2019-04-17", lhs_statistics=stats, rhs_name="2019-04-16", rhs_statistics=rhs)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.contentWindow.document.write(facets_html);
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### Schema generation from stats

# %%
sc = tfdv.infer_schema(statistics=rhs)

# %%
tfdv.display_schema(sc)
# Out:
#                                                      Type  Presence Valency  \
# Feature name
# 'userAggTable.days_since_last_dau'                    INT  optional  single
# 'emailLabelTable.hrs_to_open'                         INT  optional  single
# 'userAggTable.num_push_click_week'                    INT  optional  single
# 'userAggTable.email_click_open_rate_week'           FLOAT  optional  single
# 'userAggTable.primary_platform'                    STRING  optional  single
# 'userAggTable.dsr'                                    INT  optional  single
# 'userAggTable.num_in_app_month'                       INT  optional  single
# 'emailLabelTable.channel'                          STRING  required
# 'userAggTable.in_app_click_rate_yesterday'          FLOAT  optional  single
# 'userAggTable.num_in_app_click_yesterday'             INT  optional  single
# 'userAggTable.num_email_click_yesterday'              INT  optional  single
# 'userAggTable.num_email_open_yesterday'               INT  optional  single
# 'userAggTable.is_mau'                                 INT  optional  single
# 'emailLabelTable.user_id'                           BYTES  required
# 'userAggTable.num_in_app_click_month'                 INT  optional  single
# 'userAggTable.email_open_rate_month'                FLOAT  optional  single
# 'emailLabelTable.date'                              BYTES  required
# 'userAggTable.num_email_week'                         INT  optional  single
# 'userAggTable.num_email_click_month'                  INT  optional  single
# 'emailLabelTable.time_delivered'                    BYTES  required
# 'userAggTable.num_email_click_week'                   INT  optional  single
# 'userAggTable.num_email_yesterday'                    INT  optional  single
# 'emailLabelTable.optout_type'                      STRING  required
# 'userAggTable.num_push_month'                         INT  optional  single
# 'userAggTable.num_streams_day'                        INT  optional  single
# 'userAggTable.num_email_open_month'                   INT  optional  single
# 'userAggTable.ms_played_month'                        INT  optional  single
# 'userAggTable.push_click_rate_yesterday'            FLOAT  optional  single
# 'userAggTable.email_click_deliver_rate_month'       FLOAT  optional  single
# 'emailLabelTable.clicked'                             INT  required
# ...                                                   ...       ...     ...
# 'userAggTable.email_click_open_rate_yesterday'      FLOAT  optional  single
# 'userAggTable.product_category'                    STRING  optional  single
# 'userAggTable.num_streams_month'                      INT  optional  single
# 'userAggTable.ms_played_day'                          INT  optional  single
# 'emailLabelTable.cnt_open'                            INT  required
# 'userAggTable.is_dau'                                 INT  optional  single
# 'userAggTable.num_push_yesterday'                     INT  optional  single
# 'userAggTable.country_code'                        STRING  optional  single
# 'userAggTable.email_click_open_rate_month'          FLOAT  optional  single
# 'emailLabelTable.message_id'                        BYTES  required
# 'userAggTable.num_push_week'                          INT  optional  single
# 'userAggTable.num_in_app_week'                        INT  optional  single
# 'userAggTable.in_app_click_rate_week'               FLOAT  optional  single
# 'emailLabelTable.campaign_id'                       BYTES  required
# 'emailLabelTable.first_open'                        BYTES  optional  single
# 'userAggTable.num_push_click_yesterday'               INT  optional  single
# 'emailLabelTable.unsubscribed'                        INT  required
# 'userAggTable.num_push_click_month'                   INT  optional  single
# 'userAggTable.has_streamed_ever'                      INT  optional  single
# 'userAggTable.email_click_deliver_rate_week'        FLOAT  optional  single
# 'userAggTable.dsr_bucket'                          STRING  optional  single
# 'userAggTable.email_open_rate_week'                 FLOAT  optional  single
# 'userAggTable.num_email_month'                        INT  optional  single
# 'userAggTable.first_platform'                      STRING  optional  single
# 'userAggTable.num_in_app_click_week'                  INT  optional  single
# 'userAggTable.email_open_rate_yesterday'            FLOAT  optional  single
# 'userAggTable.email_click_deliver_rate_yesterday'   FLOAT  optional  single
# 'userAggTable.registered_today'                       INT  optional  single
# 'userAggTable.push_click_rate_week'                 FLOAT  optional  single
# 'userAggTable.push_click_rate_month'                FLOAT  optional  single
#
#                                                                             Domain
# Feature name
# 'userAggTable.days_since_last_dau'                                               -
# 'emailLabelTable.hrs_to_open'                                                    -
# 'userAggTable.num_push_click_week'                                               -
# 'userAggTable.email_click_open_rate_week'                                        -
# 'userAggTable.primary_platform'                    'userAggTable.primary_platform'
# 'userAggTable.dsr'                                                               -
# 'userAggTable.num_in_app_month'                                                  -
# 'emailLabelTable.channel'                                'emailLabelTable.channel'
# 'userAggTable.in_app_click_rate_yesterday'                                       -
# 'userAggTable.num_in_app_click_yesterday'                                        -
# 'userAggTable.num_email_click_yesterday'                                         -
# 'userAggTable.num_email_open_yesterday'                                          -
# 'userAggTable.is_mau'                                                            -
# 'emailLabelTable.user_id'                                                        -
# 'userAggTable.num_in_app_click_month'                                            -
# 'userAggTable.email_open_rate_month'                                             -
# 'emailLabelTable.date'                                                  (-inf,inf)
# 'userAggTable.num_email_week'                                                    -
# 'userAggTable.num_email_click_month'                                             -
# 'emailLabelTable.time_delivered'                                                 -
# 'userAggTable.num_email_click_week'                                              -
# 'userAggTable.num_email_yesterday'                                               -
# 'emailLabelTable.optout_type'                        'emailLabelTable.optout_type'
# 'userAggTable.num_push_month'                                                    -
# 'userAggTable.num_streams_day'                                                   -
# 'userAggTable.num_email_open_month'                                              -
# 'userAggTable.ms_played_month'                                                   -
# 'userAggTable.push_click_rate_yesterday'                                         -
# 'userAggTable.email_click_deliver_rate_month'                                    -
# 'emailLabelTable.clicked'                                                        -
# ...                                                                            ...
# 'userAggTable.email_click_open_rate_yesterday'                                   -
# 'userAggTable.product_category'                    'userAggTable.product_category'
# 'userAggTable.num_streams_month'                                                 -
# 'userAggTable.ms_played_day'                                                     -
# 'emailLabelTable.cnt_open'                                                       -
# 'userAggTable.is_dau'                                                            -
# 'userAggTable.num_push_yesterday'                                                -
# 'userAggTable.country_code'                            'userAggTable.country_code'
# 'userAggTable.email_click_open_rate_month'                                       -
# 'emailLabelTable.message_id'                                                     -
# 'userAggTable.num_push_week'                                                     -
# 'userAggTable.num_in_app_week'                                                   -
# 'userAggTable.in_app_click_rate_week'                                            -
# 'emailLabelTable.campaign_id'                                                    -
# 'emailLabelTable.first_open'                                                     -
# 'userAggTable.num_push_click_yesterday'                                          -
# 'emailLabelTable.unsubscribed'                                                   -
# 'userAggTable.num_push_click_month'                                              -
# 'userAggTable.has_streamed_ever'                                                 -
# 'userAggTable.email_click_deliver_rate_week'                                     -
# 'userAggTable.dsr_bucket'                                'userAggTable.dsr_bucket'
# 'userAggTable.email_open_rate_week'                                              -
# 'userAggTable.num_email_month'                                                   -
# 'userAggTable.first_platform'                        'userAggTable.first_platform'
# 'userAggTable.num_in_app_click_week'                                             -
# 'userAggTable.email_open_rate_yesterday'                                         -
# 'userAggTable.email_click_deliver_rate_yesterday'                                -
# 'userAggTable.registered_today'                                                  -
# 'userAggTable.push_click_rate_week'                                              -
# 'userAggTable.push_click_rate_month'                                             -
#
# [68 rows x 4 columns]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Values
# Domain
# 'userAggTable.primary_platform'  'android', 'cast', 'chrome', 'ios', 'linux', 'not_applicable', 'osx', 'other', 'playstation', 'tizen', 'unknown', 'windows', 'xbox'
# 'emailLabelTable.channel'        'email'
# 'emailLabelTable.optout_type'    'New Music - Email', 'Playlist Updates - Email', 'Product News - Email', 'Recommended Music - Email', 'Spotify News and Offers (default) - Email'
# 'userAggTable.product_type'      'ad-supported', 'non-subscriber', 'subscriber'
# 'userAggTable.product_category'  'ad-supported', 'bundle', 'campaign', 'duo', 'family', 'iap', 'non-subscriber', 'standard', 'student', 'trial-opt-in', 'trial-opt-out'
# 'userAggTable.country_code'      'AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA', 'other'
# 'userAggTable.dsr_bucket'        '0 days ago', '1 - 6 days ago', '30 - 179 days ago', '7 - 29 days ago', '>179 days ago'
# 'userAggTable.first_platform'    'android', 'ios', 'linux', 'none', 'osx', 'other', 'web', 'windows'

# %% [markdown]
# ### Data validation through schema

# %% [markdown]
# Schema inferred from training data can be used to validate test data

# %%
anomalies = tfdv.validate_statistics(stats, sc)

# %%
tfdv.display_anomalies(anomalies)
# Out:
#                                   Anomaly short description  \
# Feature name
# '\'emailLabelTable.optout_type\''  Unexpected string values
#
#                                                                                                   Anomaly long description
# Feature name
# '\'emailLabelTable.optout_type\''  Examples contain values missing from the schema: Concert Notifications - Email (~32%).

# %% [markdown]
# Training and serving data can be compared to calculate drift

# %%
anomalies = tfdv.validate_statistics(schema=sc, statistics=rhs, serving_statistics=stats)

# %%
tfdv.display_anomalies(anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# Custom thresholds can be set to warn if training and serving data are skewed

# %%
tfdv.get_feature(sc, 'userAggTable.days_since_last_dau').skew_comparator.infinity_norm.threshold = 0.01

# %% [markdown]
# Custom thresholds can be set to warn if current training data has diverged from when the model was initially developed

# %%
tfdv.get_feature(sc, 'userAggTable.days_since_last_dau').drift_comparator.infinity_norm.threshold = 0.01
