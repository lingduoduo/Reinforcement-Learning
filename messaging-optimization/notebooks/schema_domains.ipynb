# %%
from tensorflow_data_validation import GenerateStatistics, TFExampleDecoder
from tensorflow_metadata.proto.v0 import statistics_pb2, schema_pb2
import logging
from tensorflow_data_validation.utils.schema_util import get_domain, get_feature
import apache_beam as beam
import tensorflow_data_validation as tfdv
from apache_beam.options.pipeline_options import (PipelineOptions, GoogleCloudOptions,
StandardOptions, WorkerOptions, DebugOptions, SetupOptions)
from tensorflow_data_validation import statistics
from spotify_tensorflow.tfx.tfdv import TfDataValidator
from spotify_tensorflow.tfx.utils import create_setup_file
from tensorflow_data_validation import StatsOptions
import six

from spotify_tensorflow.tf_schema_utils import schema_txt_file_to_feature_spec
from spotify_tensorflow.tf_schema_utils import parse_schema_txt_file

from google.protobuf import text_format
from tensorflow.python.lib.io import file_io

# %%
schema = parse_schema_txt_file('../user-protection-pipeline/tf-supervised/src/main/python/trainers/schemas/email_open.pbtxt')
schema_spec = schema_txt_file_to_feature_spec('../user-protection-pipeline/tf-supervised/src/main/python/trainers/schemas/email_open.pbtxt')

# %%
def set_domain(schema,
               feature_name,
               domain):
  """Sets the domain for the input feature in the schema.
  If the input feature already has a domain, it is overwritten with the newly
  provided input domain. This method cannot be used to add a new global domain.
  Args:
    schema: A Schema protocol buffer.
    feature_name: The name of the feature whose domain needs to be set.
    domain: A domain protocol buffer (one of IntDomain, FloatDomain,
        StringDomain or BoolDomain) or the name of a global string domain
        present in the input schema.
  Example:
  ```python
    >>> from tensorflow_metadata.proto.v0 import schema_pb2
    >>> import tensorflow_data_validation as tfdv
    >>> schema = schema_pb2.Schema()
    >>> schema.feature.add(name='feature')
    # Setting a int domain.
    >>> int_domain = schema_pb2.IntDomain(min=3, max=5)
    >>> tfdv.set_domain(schema, "feature", int_domain)
    # Setting a string domain.
    >>> str_domain = schema_pb2.StringDomain(value=['one', 'two', 'three'])
    >>> tfdv.set_domain(schema, "feature", str_domain)
  ```
  Raises:
    TypeError: If the input schema or the domain is not of the expected type.
    ValueError: If an invalid global string domain is provided as input.
  """
  if not isinstance(schema, schema_pb2.Schema):
    raise TypeError('schema is of type %s, should be a Schema proto.' %
                    type(schema).__name__)

  if not isinstance(domain, (schema_pb2.IntDomain, schema_pb2.FloatDomain,
                             schema_pb2.StringDomain, schema_pb2.BoolDomain,
                             six.string_types)):
    raise TypeError('domain is of type %s, should be one of IntDomain, '
                    'FloatDomain, StringDomain, BoolDomain proto or a string '
                    'denoting the name of a global domain in the schema.' %
                    type(domain).__name__)

  feature = get_feature(schema, feature_name)

  if feature.WhichOneof('domain_info') is not None:
    logging.warning('Replacing existing domain of feature "%s".', feature_name)

  if isinstance(domain, schema_pb2.IntDomain):
    feature.int_domain.CopyFrom(domain)
  elif isinstance(domain, schema_pb2.FloatDomain):
    feature.float_domain.CopyFrom(domain)
  elif isinstance(domain, schema_pb2.StringDomain):
    feature.string_domain.CopyFrom(domain)
  elif isinstance(domain, schema_pb2.BoolDomain):
    feature.bool_domain.CopyFrom(domain)
  else:
    # If we have a domain name provided as input, check if we have a valid
    # global string domain with the specified name.
    found_domain = False
    for global_domain in schema.string_domain:
      if global_domain.name == domain:
        found_domain = True
        break
    if not found_domain:
      raise ValueError('Invalid global string domain "{}".'.format(domain))
    feature.domain = domain

# %%
statsFilePath ="gs://slayton_test/email_open/tf/examples/email_open.BaseInputDataV1/2019-04-01/" + \
               "20190411T155410.476299-3e9102f6a419/training/_stats.pb"
stats = tfdv.load_statistics(input_path=statsFilePath)

# %%
for field in stats.ListFields():
    for feat in field[1]:
        lst = []
        for x in feat.features:
            ftype = schema_spec[x.name].dtype.name
            fmin = x.num_stats.min
            fmax = x.num_stats.max
            print(ftype)
            if ftype == 'int64':
                domain = schema_pb2.IntDomain(min=int(fmin), max=int(fmax))
            elif ftype == 'float32':
                domain = schema_pb2.FloatDomain(min=float(fmin), max=float(fmax))
            else:
                continue
            print("Set domain for %s" % x.name)
            set_domain(schema, x.name, domain)
# Out:
# WARNING:root:Replacing existing domain of feature "userAggTable.email_click_open_rate_week".
# WARNING:root:Replacing existing domain of feature "userAggTable.in_app_click_rate_yesterday".
# WARNING:root:Replacing existing domain of feature "userAggTable.is_mau".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_open_rate_month".
# WARNING:root:Replacing existing domain of feature "emailLabelTable.clicked".
# WARNING:root:Replacing existing domain of feature "userAggTable.push_click_rate_yesterday".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_click_deliver_rate_month".
# WARNING:root:Replacing existing domain of feature "userAggTable.in_app_click_rate_month".
# WARNING:root:Replacing existing domain of feature "userAggTable.in_app_click_rate_week".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_click_open_rate_yesterday".
# WARNING:root:Replacing existing domain of feature "userAggTable.is_dau".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_click_open_rate_month".
# WARNING:root:Replacing existing domain of feature "emailLabelTable.opened".
# WARNING:root:Replacing existing domain of feature "emailLabelTable.unsubscribed".
# WARNING:root:Replacing existing domain of feature "userAggTable.has_streamed_ever".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_click_deliver_rate_week".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_open_rate_week".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_open_rate_yesterday".
# WARNING:root:Replacing existing domain of feature "userAggTable.email_click_deliver_rate_yesterday".
# WARNING:root:Replacing existing domain of feature "userAggTable.registered_today".
# WARNING:root:Replacing existing domain of feature "userAggTable.push_click_rate_week".
# WARNING:root:Replacing existing domain of feature "userAggTable.push_click_rate_month".
# int64
# Set domain for userAggTable.days_since_last_dau
# int64
# Set domain for emailLabelTable.hrs_to_open
# int64
# Set domain for userAggTable.num_push_click_week
# float32
# Set domain for userAggTable.email_click_open_rate_week
# string
# int64
# Set domain for userAggTable.dsr
# int64
# Set domain for userAggTable.num_in_app_month
# string
# float32
# Set domain for userAggTable.in_app_click_rate_yesterday
# int64
# Set domain for userAggTable.num_in_app_click_yesterday
# int64
# Set domain for userAggTable.num_email_click_yesterday
# int64
# Set domain for userAggTable.num_email_open_yesterday
# int64
# Set domain for userAggTable.is_mau
# string
# int64
# Set domain for userAggTable.num_in_app_click_month
# float32
# Set domain for userAggTable.email_open_rate_month
# string
# int64
# Set domain for userAggTable.num_email_week
# string
# string
# int64
# Set domain for emailLabelTable.clicked
# int64
# Set domain for userAggTable.num_email_yesterday
# string
# int64
# Set domain for userAggTable.num_push_month
# int64
# Set domain for userAggTable.num_streams_day
# int64
# Set domain for userAggTable.num_email_open_month
# int64
# Set domain for userAggTable.ms_played_month
# float32
# Set domain for userAggTable.push_click_rate_yesterday
# float32
# Set domain for userAggTable.email_click_deliver_rate_month
# int64
# Set domain for userAggTable.num_email_click_week
# int64
# Set domain for userAggTable.num_email_open_week
# int64
# Set domain for userAggTable.days_since_last_mau
# int64
# Set domain for emailLabelTable.cnt_click
# float32
# Set domain for userAggTable.in_app_click_rate_month
# float32
# Set domain for userAggTable.in_app_click_rate_week
# int64
# Set domain for userAggTable.num_email_click_month
# int64
# Set domain for userAggTable.num_in_app_yesterday
# string
# float32
# Set domain for userAggTable.email_click_open_rate_yesterday
# string
# int64
# Set domain for userAggTable.num_streams_month
# int64
# Set domain for userAggTable.ms_played_day
# int64
# Set domain for emailLabelTable.cnt_open
# int64
# Set domain for userAggTable.is_dau
# int64
# Set domain for userAggTable.num_push_yesterday
# string
# float32
# Set domain for userAggTable.email_click_open_rate_month
# string
# int64
# Set domain for userAggTable.num_push_week
# int64
# Set domain for userAggTable.num_in_app_week
# int64
# Set domain for emailLabelTable.opened
# string
# string
# int64
# Set domain for userAggTable.num_push_click_yesterday
# int64
# Set domain for emailLabelTable.unsubscribed
# int64
# Set domain for userAggTable.num_push_click_month
# int64
# Set domain for userAggTable.has_streamed_ever
# float32
# Set domain for userAggTable.email_click_deliver_rate_week
# string
# float32
# Set domain for userAggTable.email_open_rate_week
# int64
# Set domain for userAggTable.num_email_month
# string
# int64
# Set domain for userAggTable.num_in_app_click_week
# float32
# Set domain for userAggTable.email_open_rate_yesterday
# float32
# Set domain for userAggTable.email_click_deliver_rate_yesterday
# int64
# Set domain for userAggTable.registered_today
# float32
# Set domain for userAggTable.push_click_rate_week
# float32
# Set domain for userAggTable.push_click_rate_month

# %%
get_feature(schema=schema, feature_name="emailLabelTable.clicked")
#schema_spec["userAggTable.user_id"].dtype.name
# Out:
# name: "emailLabelTable.clicked"
# value_count {
#   min: 1
#   max: 1
# }
# type: INT
# int_domain {
#   min: 0
#   max: 1
# }
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }

# %%
schema
# Out:
# feature {
#   name: "userAggTable.days_since_last_dau"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1866
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.hrs_to_open"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 167
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_push_click_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 4
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_click_open_rate_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 2.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.primary_platform"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "userAggTable.primary_platform"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.dsr"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 4340
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_in_app_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 217
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.channel"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "emailLabelTable.channel"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.in_app_click_rate_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 0.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_in_app_click_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_click_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_open_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.is_mau"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.user_id"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_in_app_click_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 34
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.optout_type"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "emailLabelTable.optout_type"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.date"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   int_domain {
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 58
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.product_type"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "userAggTable.product_type"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.time_delivered"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_click_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 4
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_open_rate_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_push_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 11
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_streams_day"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 5500
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_open_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 25
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.ms_played_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 8341506633
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.push_click_rate_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 0.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_click_deliver_rate_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.clicked"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_open_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 7
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.days_since_last_mau"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1837
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.cnt_click"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 50
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.in_app_click_rate_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.opened"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_click_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 6
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_in_app_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.user_id"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_click_open_rate_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 0.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.product_category"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "userAggTable.product_category"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_streams_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 65360
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.ms_played_day"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1149221630
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.cnt_open"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 99
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.is_dau"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_push_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.country_code"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "userAggTable.country_code"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_click_open_rate_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 4.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.message_id"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_push_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 7
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_in_app_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 201
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.in_app_click_rate_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.campaign_id"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.first_open"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_push_click_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "emailLabelTable.unsubscribed"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_push_click_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 9
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.has_streamed_ever"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_click_deliver_rate_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.dsr_bucket"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "userAggTable.dsr_bucket"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_open_rate_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_email_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 1305
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.first_platform"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "userAggTable.first_platform"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.num_in_app_click_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 0
#     max: 9
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_open_rate_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 0.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.email_click_deliver_rate_yesterday"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 0.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.registered_today"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: INT
#   int_domain {
#     min: 1
#     max: 1
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.push_click_rate_week"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "userAggTable.push_click_rate_month"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   float_domain {
#     min: 0.0
#     max: 1.0
#   }
#   presence {
#     min_count: 1
#   }
# }
# string_domain {
#   name: "userAggTable.primary_platform"
#   value: "android"
#   value: "cast"
#   value: "chrome"
#   value: "ios"
#   value: "linux"
#   value: "not_applicable"
#   value: "osx"
#   value: "other"
#   value: "playstation"
#   value: "tizen"
#   value: "unknown"
#   value: "windows"
#   value: "xbox"
# }
# string_domain {
#   name: "emailLabelTable.channel"
#   value: "email"
# }
# string_domain {
#   name: "emailLabelTable.optout_type"
#   value: "New Music - Email"
#   value: "Playlist Updates - Email"
#   value: "Product News - Email"
#   value: "Recommended Music - Email"
#   value: "Spotify News and Offers (default) - Email"
# }
# string_domain {
#   name: "userAggTable.product_type"
#   value: "ad-supported"
#   value: "non-subscriber"
#   value: "subscriber"
# }
# string_domain {
#   name: "userAggTable.product_category"
#   value: "ad-supported"
#   value: "bundle"
#   value: "campaign"
#   value: "duo"
#   value: "family"
#   value: "iap"
#   value: "non-subscriber"
#   value: "standard"
#   value: "student"
#   value: "trial-opt-in"
#   value: "trial-opt-out"
# }
# string_domain {
#   name: "userAggTable.country_code"
#   value: "AD"
#   value: "AE"
#   value: "AR"
#   value: "AT"
#   value: "AU"
#   value: "BE"
#   value: "BG"
#   value: "BH"
#   value: "BO"
#   value: "BR"
#   value: "CA"
#   value: "CH"
#   value: "CL"
#   value: "CO"
#   value: "CR"
#   value: "CY"
#   value: "CZ"
#   value: "DE"
#   value: "DK"
#   value: "DO"
#   value: "DZ"
#   value: "EC"
#   value: "EE"
#   value: "EG"
#   value: "ES"
#   value: "FI"
#   value: "FR"
#   value: "GB"
#   value: "GR"
#   value: "GT"
#   value: "HK"
#   value: "HN"
#   value: "HU"
#   value: "ID"
#   value: "IE"
#   value: "IL"
#   value: "IN"
#   value: "IS"
#   value: "IT"
#   value: "JO"
#   value: "JP"
#   value: "KW"
#   value: "LB"
#   value: "LI"
#   value: "LT"
#   value: "LU"
#   value: "LV"
#   value: "MA"
#   value: "MC"
#   value: "MT"
#   value: "MX"
#   value: "MY"
#   value: "NI"
#   value: "NL"
#   value: "NO"
#   value: "NZ"
#   value: "OM"
#   value: "PA"
#   value: "PE"
#   value: "PH"
#   value: "PL"
#   value: "PS"
#   value: "PT"
#   value: "PY"
#   value: "QA"
#   value: "RO"
#   value: "RU"
#   value: "SA"
#   value: "SE"
#   value: "SG"
#   value: "SK"
#   value: "SV"
#   value: "TH"
#   value: "TN"
#   value: "TR"
#   value: "TW"
#   value: "US"
#   value: "UY"
#   value: "VN"
#   value: "ZA"
#   value: "other"
# }
# string_domain {
#   name: "userAggTable.dsr_bucket"
#   value: "0 days ago"
#   value: "1 - 6 days ago"
#   value: "30 - 179 days ago"
#   value: "7 - 29 days ago"
#   value: ">179 days ago"
# }
# string_domain {
#   name: "userAggTable.first_platform"
#   value: "android"
#   value: "ios"
#   value: "linux"
#   value: "none"
#   value: "osx"
#   value: "other"
#   value: "web"
#   value: "windows"
# }

# %%
def write_schema_text(schema, output_path):
  """Writes input schema to a file in text format.
  Args:
    schema: A Schema protocol buffer.
    output_path: File path to write the input schema.
  Raises:
    TypeError: If the input schema is not of the expected type.
  """
  if not isinstance(schema, schema_pb2.Schema):
    raise TypeError('schema is of type %s, should be a Schema proto.' %
                    type(schema).__name__)

  schema_text = text_format.MessageToString(schema)
  file_io.write_string_to_file(output_path, schema_text)

# %%
write_schema_text(schema, '../user-protection-pipeline/tf-supervised/src/main/python/trainers/schemas/email_open.pbtxt')
